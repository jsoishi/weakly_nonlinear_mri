# %% [markdown]
# The nonlinear equations are:
#
# $\partial_t \mathbf{u} + \mathbf{u} \cdot \nabla \mathbf{u} - 2\Omega_0 \mathbf{\hat{z}} \times \mathbf{u} - q\Omega_0 u_x \mathbf{\hat{y}} - C\mathbf{b} \cdot \nabla\mathbf{b} - CB_0\partial_z\mathbf{b} = -\nabla\varpi + \frac{1}{R}\nabla^2\mathbf{u}$
#
# $\partial_t\mathbf{b} + \mathbf{u} \cdot \nabla \mathbf{b} - \mathbf{b}\cdot\nabla\mathbf{u} + q\Omega_0b_x\mathbf{\hat{y}} - B_0\partial_z\mathbf{u} = \frac{1}{R_m}\nabla^2\mathbf{b}$
#
# Plus incompressibility and the solenoidal magnetic field constraint:
#
# $\nabla \cdot \mathbf{u} = 0$ and $\nabla \cdot \mathbf{b} = 0$

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sympy import *
from sympy.interactive import printing
printing.init_printing(use_latex=True)

# %%
import sympy
print(sympy.__version__)
# Out:
# 0.7.6.1

# %%
R, Rm, kx, ky, kz, omega, q, B0, Co, eps = symbols("R R_m k_x k_y k_z Omega_0 q B_0 C epsilon", real=True)
s = symbols("s",)

# %% [markdown]
# The linearized equations are as follows:
#
# $\left(s + \frac{1}{R}\left(k_x^2+k_z^2\right)\right)u_x - 2\Omega_0u_y - iCB_0k_zb_x + iCB_0k_xb_z + ik_x\varpi = 0$
#
# $\Omega_0\left(2-q\right)u_x + \left(s + \frac{1}{R}\left(k_x^2+k_z^2\right)\right)u_y - iCB_0k_zb_y = 0$
#
# $\left(s + \frac{1}{R}\left(k_x^2+k_z^2\right)\right)u_z - iCB_0k_zb_z + ik_z\varpi = 0$
#
# $-iB_0k_zu_x + \left(s + \frac{1}{R_m}\left(k_x^2+k_z^2\right)\right)b_x = 0$
#
# $-iB_0k_zu_y + \Omega_0qb_x + \left(s + \frac{1}{R_m}\left(k_x^2+k_z^2\right)\right)b_y = 0$
#
# $-iB_0k_zu_z + \left(s + \frac{1}{R_m}\left(k_x^2+k_z^2\right)\right)b_z = 0$
#
# Along with the two constraints:
#
# $ik_xu_x + ik_zu_z = 0$
#
# $ik_xb_x + ik_zb_z = 0$
#
# But we ignore the second constraint for now.
#
# The state vector is:
# $\mathbf{x} = \left[u_x, u_y, u_z, b_x, b_y, b_z, \varpi \right]^{T}$

# %%
M = Matrix([[s+(1/R)*(kx**2+kz**2), -2*omega, 0, -I*Co*B0*kz, 0, I*B0*Co*kx, I*kx],
            [omega*(2-q), s+(1/R)*(kx**2+kz**2), 0, 0, -I*Co*B0*kz, 0, 0],
            [0, 0, s+(1/R)*(kx**2+kz**2), 0, 0, 0, I*kz],
            [-I*B0*kz, 0, 0, s+(1/Rm)*(kx**2+kz**2), 0, 0, 0],
            [0, -I*B0*kz, 0, q*omega, s + (1/Rm)*(kx**2+kz**2), 0, 0],
            [0, 0, -I*B0*kz, 0, 0, s+(1/Rm)*(kx**2 + kz**2), 0],
            [I*kx, 0, I*kz, 0, 0, 0, 0]])
M
# Out:
# ⎡      2      2
# ⎢    kₓ  + k_z
# ⎢s + ──────────      -2⋅Ω₀             0          -ⅈ⋅B₀⋅C⋅k_z          0
# ⎢        R
# ⎢
# ⎢                      2      2
# ⎢                    kₓ  + k_z
# ⎢ Ω₀⋅(-q + 2)    s + ──────────        0               0          -ⅈ⋅B₀⋅C⋅k_z
# ⎢                        R
# ⎢
# ⎢                                      2      2
# ⎢                                    kₓ  + k_z
# ⎢      0               0         s + ──────────        0               0
# ⎢                                        R
# ⎢
# ⎢                                                      2      2
# ⎢                                                    kₓ  + k_z
# ⎢  -ⅈ⋅B₀⋅k_z           0               0         s + ──────────        0
# ⎢                                                       R_m
# ⎢
# ⎢                                                                      2
# ⎢                                                                    kₓ  + k_z
# ⎢      0           -ⅈ⋅B₀⋅k_z           0              Ω₀⋅q       s + ─────────
# ⎢                                                                       R_m
# ⎢
# ⎢
# ⎢
# ⎢      0               0           -ⅈ⋅B₀⋅k_z           0               0
# ⎢
# ⎢
# ⎣     ⅈ⋅kₓ             0             ⅈ⋅k_z             0               0
#
#                         ⎤
#                         ⎥
#      ⅈ⋅B₀⋅C⋅kₓ     ⅈ⋅kₓ ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#          0           0  ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#          0         ⅈ⋅k_z⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#          0           0  ⎥
#                         ⎥
#                         ⎥
# 2                       ⎥
#                         ⎥
# ─        0           0  ⎥
#                         ⎥
#                         ⎥
#          2      2       ⎥
#        kₓ  + k_z        ⎥
#    s + ──────────    0  ⎥
#           R_m           ⎥
#                         ⎥
#          0           0  ⎦

# %%
MM = Matrix([[s, -2*omega, 0, -I*Co*B0*kz, 0, I*B0*Co*kx, I*kx],
            [omega*(2-q), s, 0, 0, -I*Co*B0*kz, 0, 0],
            [0, 0, s, 0, 0, 0, I*kz],
            [-I*B0*kz, 0, 0, s, 0, 0, 0],
            [0, -I*B0*kz, 0, q*omega, s, 0, 0],
            [0, 0, -I*B0*kz, 0, 0, s, 0],
            [I*kx, 0, I*kz, 0, 0, 0, 0]])
MM
# Out:
# ⎡     s         -2⋅Ω₀        0      -ⅈ⋅B₀⋅C⋅k_z       0       ⅈ⋅B₀⋅C⋅kₓ  ⅈ⋅kₓ
# ⎢
# ⎢Ω₀⋅(-q + 2)      s          0           0       -ⅈ⋅B₀⋅C⋅k_z      0        0
# ⎢
# ⎢     0           0          s           0            0           0      ⅈ⋅k_z
# ⎢
# ⎢ -ⅈ⋅B₀⋅k_z       0          0           s            0           0        0
# ⎢
# ⎢     0       -ⅈ⋅B₀⋅k_z      0         Ω₀⋅q           s           0        0
# ⎢
# ⎢     0           0      -ⅈ⋅B₀⋅k_z       0            0           s        0
# ⎢
# ⎣   ⅈ⋅kₓ          0        ⅈ⋅k_z         0            0           0        0
#
# ⎤
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎦

# %%
ddd = MM.det()
sim = ddd.subs(kx, 0)

# %%
dd = M.det()

# %%
dd.collect(s)
# Out:
#   4  2   4    4       4  2   2    6     4  2    8       2     2   2    4
# B₀ ⋅C ⋅kₓ ⋅k_z    2⋅B₀ ⋅C ⋅kₓ ⋅k_z    B₀ ⋅C ⋅k_z    2⋅B₀ ⋅C⋅Ω₀ ⋅kₓ ⋅k_z ⋅q   2
# ─────────────── + ───────────────── + ─────────── - ────────────────────── - ─
#       R_m                R_m              R_m                R_m
#
#
#    2     2    6         2     8    2       2     6    4        2     4    6
# ⋅B₀ ⋅C⋅Ω₀ ⋅k_z ⋅q   2⋅B₀ ⋅C⋅kₓ ⋅k_z    8⋅B₀ ⋅C⋅kₓ ⋅k_z    12⋅B₀ ⋅C⋅kₓ ⋅k_z
# ───────────────── + ──────────────── + ──────────────── + ───────────────── +
#       R_m                     2                  2                   2
#                          R⋅R_m              R⋅R_m               R⋅R_m
#
#     2     2    8       2      10       2   6    2         2   6    2       2
# 8⋅B₀ ⋅C⋅kₓ ⋅k_z    2⋅B₀ ⋅C⋅k_z     2⋅Ω₀ ⋅kₓ ⋅k_z ⋅q   4⋅Ω₀ ⋅kₓ ⋅k_z    6⋅Ω₀ ⋅k
# ──────────────── + ───────────── - ──────────────── + ────────────── - ───────
#           2                 2               3                 3
#      R⋅R_m             R⋅R_m             R_m               R_m               R
#
#  4    4          2   4    4       2   2    6          2   2    6       2    8
# ₓ ⋅k_z ⋅q   12⋅Ω₀ ⋅kₓ ⋅k_z    6⋅Ω₀ ⋅kₓ ⋅k_z ⋅q   12⋅Ω₀ ⋅kₓ ⋅k_z    2⋅Ω₀ ⋅k_z ⋅
# ───────── + ─────────────── - ──────────────── + ─────────────── - ───────────
#   3                  3                 3                  3               3
# _m                R_m               R_m                R_m             R_m
#
#         2    8                        ⎛    4       2    2        4       4
# q   4⋅Ω₀ ⋅k_z     5 ⎛  2      2⎞    4 ⎜3⋅kₓ    6⋅kₓ ⋅k_z    3⋅k_z    2⋅kₓ    4
# ─ + ────────── + s ⋅⎝kₓ  + k_z ⎠ + s ⋅⎜───── + ────────── + ────── + ───── + ─
#           3                           ⎝ R_m       R_m        R_m       R
#        R_m
#
#    2    2        4⎞      ⎛
# ⋅kₓ ⋅k_z    2⋅k_z ⎟    3 ⎜    2     2    2       2      4       2    2
# ───────── + ──────⎟ + s ⋅⎜2⋅B₀ ⋅C⋅kₓ ⋅k_z  + 2⋅B₀ ⋅C⋅k_z  - 2⋅Ω₀ ⋅k_z ⋅q + 4⋅Ω
#    R          R   ⎠      ⎜
#                          ⎝
#
#               6       4    2       2    4        6       6        4    2
#  2    2   3⋅kₓ    9⋅kₓ ⋅k_z    9⋅kₓ ⋅k_z    3⋅k_z    6⋅kₓ    18⋅kₓ ⋅k_z    18⋅
# ₀ ⋅k_z  + ───── + ────────── + ────────── + ────── + ───── + ─────────── + ───
#               2         2            2          2    R⋅R_m      R⋅R_m
#            R_m       R_m          R_m        R_m
#
#   2    4        6     6       4    2       2    4      6⎞      ⎛    2     4
# kₓ ⋅k_z    6⋅k_z    kₓ    3⋅kₓ ⋅k_z    3⋅kₓ ⋅k_z    k_z ⎟    2 ⎜4⋅B₀ ⋅C⋅kₓ ⋅k_
# ──────── + ────── + ─── + ────────── + ────────── + ────⎟ + s ⋅⎜──────────────
# R⋅R_m      R⋅R_m      2        2            2         2 ⎟      ⎜      R_m
#                      R        R            R         R  ⎠      ⎝
#
#  2       2     2    4       2      6       2     4    2       2     2    4
# z    8⋅B₀ ⋅C⋅kₓ ⋅k_z    4⋅B₀ ⋅C⋅k_z    2⋅B₀ ⋅C⋅kₓ ⋅k_z    4⋅B₀ ⋅C⋅kₓ ⋅k_z    2
# ── + ──────────────── + ──────────── + ──────────────── + ──────────────── + ─
#            R_m              R_m               R                  R
#
#
#    2      6       2   2    2          2   2    2       2    4          2    4
# ⋅B₀ ⋅C⋅k_z    6⋅Ω₀ ⋅kₓ ⋅k_z ⋅q   12⋅Ω₀ ⋅kₓ ⋅k_z    6⋅Ω₀ ⋅k_z ⋅q   12⋅Ω₀ ⋅k_z
# ─────────── - ──────────────── + ─────────────── - ──────────── + ───────────
#     R               R_m                R_m             R_m            R_m
#
#
#     8        6    2       4    4       2    6      8       8         6    2
#   kₓ     4⋅kₓ ⋅k_z    6⋅kₓ ⋅k_z    4⋅kₓ ⋅k_z    k_z    6⋅kₓ     24⋅kₓ ⋅k_z
# + ──── + ────────── + ────────── + ────────── + ──── + ────── + ─────────── +
#      3         3            3            3         3        2           2
#   R_m       R_m          R_m          R_m       R_m    R⋅R_m       R⋅R_m
#
#      4    4        2    6        8       8         6    2        4    4
# 36⋅kₓ ⋅k_z    24⋅kₓ ⋅k_z    6⋅k_z    3⋅kₓ     12⋅kₓ ⋅k_z    18⋅kₓ ⋅k_z    12⋅k
# ─────────── + ─────────── + ────── + ────── + ─────────── + ─────────── + ────
#         2             2          2    2           2             2
#    R⋅R_m         R⋅R_m      R⋅R_m    R ⋅R_m      R ⋅R_m        R ⋅R_m        R
#
#  2    6        8⎞     ⎛
# ₓ ⋅k_z    3⋅k_z ⎟     ⎜  4  2   2    4     4  2    6       2     2    4     2⋅
# ─────── + ──────⎟ + s⋅⎜B₀ ⋅C ⋅kₓ ⋅k_z  + B₀ ⋅C ⋅k_z  - 2⋅B₀ ⋅C⋅Ω₀ ⋅k_z ⋅q + ──
# 2          2    ⎟     ⎜
#  ⋅R_m     R ⋅R_m⎠     ⎝
#
#   2     6    2       2     4    4       2     2    6       2      8       2
# B₀ ⋅C⋅kₓ ⋅k_z    6⋅B₀ ⋅C⋅kₓ ⋅k_z    6⋅B₀ ⋅C⋅kₓ ⋅k_z    2⋅B₀ ⋅C⋅k_z    4⋅B₀ ⋅C⋅
# ────────────── + ──────────────── + ──────────────── + ──────────── + ────────
#        2                  2                  2                2            R⋅R
#     R_m                R_m                R_m              R_m
#
#   6    2        2     4    4        2     2    6       2      8       2   4
# kₓ ⋅k_z    12⋅B₀ ⋅C⋅kₓ ⋅k_z    12⋅B₀ ⋅C⋅kₓ ⋅k_z    4⋅B₀ ⋅C⋅k_z    6⋅Ω₀ ⋅kₓ ⋅k_
# ──────── + ───────────────── + ───────────────── + ──────────── - ────────────
# _m               R⋅R_m               R⋅R_m            R⋅R_m                2
#                                                                         R_m
#
#  2          2   4    2        2   2    4          2   2    4       2    6
# z ⋅q   12⋅Ω₀ ⋅kₓ ⋅k_z    12⋅Ω₀ ⋅kₓ ⋅k_z ⋅q   24⋅Ω₀ ⋅kₓ ⋅k_z    6⋅Ω₀ ⋅k_z ⋅q
# ──── + ─────────────── - ───────────────── + ─────────────── - ──────────── +
#                 2                  2                  2               2
#              R_m                R_m                R_m             R_m
#
#      2    6       10        8    2        6    4        4    6        2    8
# 12⋅Ω₀ ⋅k_z    2⋅kₓ     10⋅kₓ ⋅k_z    20⋅kₓ ⋅k_z    20⋅kₓ ⋅k_z    10⋅kₓ ⋅k_z
# ─────────── + ────── + ─────────── + ─────────── + ─────────── + ─────────── +
#        2           3           3             3             3             3
#     R_m       R⋅R_m       R⋅R_m         R⋅R_m         R⋅R_m         R⋅R_m
#
#       10        10        8    2        6    4        4    6        2    8
#  2⋅k_z      3⋅kₓ     15⋅kₓ ⋅k_z    30⋅kₓ ⋅k_z    30⋅kₓ ⋅k_z    15⋅kₓ ⋅k_z    3
#  ─────── + ─────── + ─────────── + ─────────── + ─────────── + ─────────── + ─
#        3    2    2      2    2        2    2        2    2        2    2
#   R⋅R_m    R ⋅R_m      R ⋅R_m        R ⋅R_m        R ⋅R_m        R ⋅R_m      R
#
#     10⎞       12        10    2        8    4        6    6        4    8
# ⋅k_z  ⎟     kₓ      6⋅kₓ  ⋅k_z    15⋅kₓ ⋅k_z    20⋅kₓ ⋅k_z    15⋅kₓ ⋅k_z    6⋅
# ──────⎟ + ─────── + ─────────── + ─────────── + ─────────── + ─────────── + ──
# 2    2⎟    2    3      2    3        2    3        2    3        2    3
#  ⋅R_m ⎠   R ⋅R_m      R ⋅R_m        R ⋅R_m        R ⋅R_m        R ⋅R_m
#
#   2    10       12
# kₓ ⋅k_z      k_z
# ───────── + ───────
#  2    3      2    3
# R ⋅R_m      R ⋅R_m

# %%
dispsub = dd.subs(R, Rm/1.00e-03).subs(Co, 25).subs(omega, 1).subs(q, 1.5).subs(s, 0).subs(kz, 0.75).subs(kx, 0)#.subs(B0, 1-eps**2)#.subs(Rm, 4.9).subs(eps, 0.5)

# %%
dispsub.subs(Rm, 4.9).expand()
# Out:
#                    4                            2
# 12.2687395881204⋅B₀  - -2.61730988593929⋅(-1)⋅B₀  + 0.000754709095724234

# %%
sympy.solvers.solve(Eq(dispsub.subs(Rm, 5.1).expand()), B0)
# Out:
# [-0.461565661026845, -0.0169924627520132, 0.0169924627520132, 0.46156566102684
# 5]

# %%
Rm = 5.1, B0 = 0.0169924627520132,0.461565661026845

# %%
Infinity = oo

# %%
aa = dd.subs(R, oo).subs(Rm, oo)
simplify(aa)
# Out:
#   ⎛  4  2   2    4     4  2    6       2     2    4         2     2    2  2
# s⋅⎝B₀ ⋅C ⋅kₓ ⋅k_z  + B₀ ⋅C ⋅k_z  - 2⋅B₀ ⋅C⋅Ω₀ ⋅k_z ⋅q + 2⋅B₀ ⋅C⋅kₓ ⋅k_z ⋅s  +
#
#     2      4  2       2    2    2       2    2  2     2  4      2  4⎞
# 2⋅B₀ ⋅C⋅k_z ⋅s  - 2⋅Ω₀ ⋅k_z ⋅q⋅s  + 4⋅Ω₀ ⋅k_z ⋅s  + kₓ ⋅s  + k_z ⋅s ⎠

# %%
#Umurhan+ a4 term
jj = (Co/(Rm*Co)**4)*((kx**2+kz**2)*Co*(((Co*Rm/R)*(kx**2 + kz**2)**2 + kz**2*Rm**2*Co**2)**2) + 2*(2-q)*Rm**2*Co**3*(kx**2+kz**2)**2*kz**2 - 2*q*Rm**4*Co**4*kz**4)
jj.expand().subs(Rm, Infinity).subs(R, Infinity)
# Out:
#  2   2    4    2    6          4
# C ⋅kₓ ⋅k_z  + C ⋅k_z  - 2⋅C⋅k_z ⋅q

# %%
(simplify(aa.subs(B0, 1).subs(omega, 1))/s).subs(s,0)
# Out:
#  2   2    4    2    6          4
# C ⋅kₓ ⋅k_z  + C ⋅k_z  - 2⋅C⋅k_z ⋅q

# %%
coeff = 1/(Rm*s+kx**2+kz**2)*Rm
d1 = factor(dd)*coeff
a4 = expand(d1).subs(s,0).subs(B0, 1).subs(omega, 1)
a4
# Out:
#                                            6    2         4    4         2
#  2   2    4    2    6          4     2⋅C⋅kₓ ⋅k_z    6⋅C⋅kₓ ⋅k_z    6⋅C⋅kₓ ⋅k_z
# C ⋅kₓ ⋅k_z  + C ⋅k_z  - 2⋅C⋅k_z ⋅q + ──────────── + ──────────── + ───────────
#                                         R⋅R_m          R⋅R_m          R⋅R_m
#
#
# 6          8       4    2         4    2       2    4         2    4        6
#     2⋅C⋅k_z    2⋅kₓ ⋅k_z ⋅q   4⋅kₓ ⋅k_z    4⋅kₓ ⋅k_z ⋅q   8⋅kₓ ⋅k_z    2⋅k_z ⋅
# ─ + ──────── - ──────────── + ────────── - ──────────── + ────────── - ───────
#      R⋅R_m            2             2             2             2           2
#                    R_m           R_m           R_m           R_m         R_m
#
#          6       10        8    2        6    4        4    6       2    8
# q   4⋅k_z      kₓ      5⋅kₓ ⋅k_z    10⋅kₓ ⋅k_z    10⋅kₓ ⋅k_z    5⋅kₓ ⋅k_z
# ─ + ────── + ─────── + ────────── + ─────────── + ─────────── + ────────── + ─
#         2     2    2     2    2        2    2        2    2       2    2
#      R_m     R ⋅R_m     R ⋅R_m        R ⋅R_m        R ⋅R_m       R ⋅R_m      R
#
#    10
# k_z
# ──────
# 2    2
#  ⋅R_m

# %%
expand(jj)
# Out:
#                                            6    2         4    4         2
#  2   2    4    2    6          4     2⋅C⋅kₓ ⋅k_z    6⋅C⋅kₓ ⋅k_z    6⋅C⋅kₓ ⋅k_z
# C ⋅kₓ ⋅k_z  + C ⋅k_z  - 2⋅C⋅k_z ⋅q + ──────────── + ──────────── + ───────────
#                                         R⋅R_m          R⋅R_m          R⋅R_m
#
#
# 6          8       4    2         4    2       2    4         2    4        6
#     2⋅C⋅k_z    2⋅kₓ ⋅k_z ⋅q   4⋅kₓ ⋅k_z    4⋅kₓ ⋅k_z ⋅q   8⋅kₓ ⋅k_z    2⋅k_z ⋅
# ─ + ──────── - ──────────── + ────────── - ──────────── + ────────── - ───────
#      R⋅R_m            2             2             2             2           2
#                    R_m           R_m           R_m           R_m         R_m
#
#          6       10        8    2        6    4        4    6       2    8
# q   4⋅k_z      kₓ      5⋅kₓ ⋅k_z    10⋅kₓ ⋅k_z    10⋅kₓ ⋅k_z    5⋅kₓ ⋅k_z
# ─ + ────── + ─────── + ────────── + ─────────── + ─────────── + ────────── + ─
#         2     2    2     2    2        2    2        2    2       2    2
#      R_m     R ⋅R_m     R ⋅R_m        R ⋅R_m        R ⋅R_m       R ⋅R_m      R
#
#    10
# k_z
# ──────
# 2    2
#  ⋅R_m

# %%
collect(d1, Rm*Co)
# Out:
#  ⎛ 2    2 ⎛    4  2   2    4     4  2    6⎞        2 ⎛    2   2  2    4
# -⎝C ⋅R_m ⋅⎝- B₀ ⋅R ⋅kₓ ⋅k_z  - B₀ ⋅R ⋅k_z ⎠ + C⋅R_m ⋅⎝2⋅B₀ ⋅Ω₀ ⋅R ⋅k_z ⋅q - 2⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2  2   2    2  2       2  2    4  2       2     4    2         2     2    4
# B₀ ⋅R ⋅kₓ ⋅k_z ⋅s  - 2⋅B₀ ⋅R ⋅k_z ⋅s  - 2⋅B₀ ⋅R⋅kₓ ⋅k_z ⋅s - 4⋅B₀ ⋅R⋅kₓ ⋅k_z ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2      6  ⎞         ⎛      2  2   4    2         2  2   2    4
# s - 2⋅B₀ ⋅R⋅k_z ⋅s⎠ + C⋅R_m⋅⎝- 2⋅B₀ ⋅R ⋅kₓ ⋅k_z ⋅s - 4⋅B₀ ⋅R ⋅kₓ ⋅k_z ⋅s - 2⋅B
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2  2    6         2     6    2       2     4    4       2     2    6       2
# ₀ ⋅R ⋅k_z ⋅s - 2⋅B₀ ⋅R⋅kₓ ⋅k_z  - 6⋅B₀ ⋅R⋅kₓ ⋅k_z  - 6⋅B₀ ⋅R⋅kₓ ⋅k_z  - 2⋅B₀ ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      8⎞       2  2    2    2    2       2  2    2    2  2       2  2       2
# R⋅k_z ⎠ + 2⋅Ω₀ ⋅R ⋅R_m ⋅k_z ⋅q⋅s  - 4⋅Ω₀ ⋅R ⋅R_m ⋅k_z ⋅s  + 4⋅Ω₀ ⋅R ⋅R_m⋅kₓ ⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2           2  2       2    2         2  2        4           2  2        4
# _z ⋅q⋅s - 8⋅Ω₀ ⋅R ⋅R_m⋅kₓ ⋅k_z ⋅s + 4⋅Ω₀ ⋅R ⋅R_m⋅k_z ⋅q⋅s - 8⋅Ω₀ ⋅R ⋅R_m⋅k_z ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2  2   4    2         2  2   4    2       2  2   2    4         2  2
# s + 2⋅Ω₀ ⋅R ⋅kₓ ⋅k_z ⋅q - 4⋅Ω₀ ⋅R ⋅kₓ ⋅k_z  + 4⋅Ω₀ ⋅R ⋅kₓ ⋅k_z ⋅q - 8⋅Ω₀ ⋅R ⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2    4       2  2    6         2  2    6    2    2   2  4    2    2    2  4
# ₓ ⋅k_z  + 2⋅Ω₀ ⋅R ⋅k_z ⋅q - 4⋅Ω₀ ⋅R ⋅k_z  - R ⋅R_m ⋅kₓ ⋅s  - R ⋅R_m ⋅k_z ⋅s  -
# ──────────────────────────────────────────────────────────────────────────────
#                                                2    2
#                                               R ⋅R_m
#
#     2       4  3      2       2    2  3      2        4  3    2   6  2      2
#  2⋅R ⋅R_m⋅kₓ ⋅s  - 4⋅R ⋅R_m⋅kₓ ⋅k_z ⋅s  - 2⋅R ⋅R_m⋅k_z ⋅s  - R ⋅kₓ ⋅s  - 3⋅R ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   4    2  2      2   2    4  2    2    6  2          2   4  3          2   2
# kₓ ⋅k_z ⋅s  - 3⋅R ⋅kₓ ⋅k_z ⋅s  - R ⋅k_z ⋅s  - 2⋅R⋅R_m ⋅kₓ ⋅s  - 4⋅R⋅R_m ⋅kₓ ⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2  3          2    4  3             6  2              4    2  2
# _z ⋅s  - 2⋅R⋅R_m ⋅k_z ⋅s  - 4⋅R⋅R_m⋅kₓ ⋅s  - 12⋅R⋅R_m⋅kₓ ⋅k_z ⋅s  - 12⋅R⋅R_m⋅k
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2    4  2              6  2         8           6    2            4    4
# ₓ ⋅k_z ⋅s  - 4⋅R⋅R_m⋅k_z ⋅s  - 2⋅R⋅kₓ ⋅s - 8⋅R⋅kₓ ⋅k_z ⋅s - 12⋅R⋅kₓ ⋅k_z ⋅s -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2    6            8        2   6  2        2   4    2  2        2   2
# 8⋅R⋅kₓ ⋅k_z ⋅s - 2⋅R⋅k_z ⋅s - R_m ⋅kₓ ⋅s  - 3⋅R_m ⋅kₓ ⋅k_z ⋅s  - 3⋅R_m ⋅kₓ ⋅k_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  4  2      2    6  2           8             6    2              4    4
# z ⋅s  - R_m ⋅k_z ⋅s  - 2⋅R_m⋅kₓ ⋅s - 8⋅R_m⋅kₓ ⋅k_z ⋅s - 12⋅R_m⋅kₓ ⋅k_z ⋅s - 8⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2    6              8       10       8    2        6    4        4    6
# R_m⋅kₓ ⋅k_z ⋅s - 2⋅R_m⋅k_z ⋅s - kₓ   - 5⋅kₓ ⋅k_z  - 10⋅kₓ ⋅k_z  - 10⋅kₓ ⋅k_z
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2    8      10⎞
# - 5⋅kₓ ⋅k_z  - k_z  ⎠
# ──────────────────────

# %%
#d1 is the dispersion relation (with one power of s factored out)
disp = expand(d1).subs(B0, 1).subs(omega, 1)
disp
# Out:
#                                                                            4
#  2   2    4    2    6         2    2  2          4            4  2   2⋅C⋅kₓ ⋅k
# C ⋅kₓ ⋅k_z  + C ⋅k_z  + 2⋅C⋅kₓ ⋅k_z ⋅s  - 2⋅C⋅k_z ⋅q + 2⋅C⋅k_z ⋅s  + ─────────
#                                                                           R_m
#
#
#   2           2    4            6           4    2           2    4
# _z ⋅s   4⋅C⋅kₓ ⋅k_z ⋅s   2⋅C⋅k_z ⋅s   2⋅C⋅kₓ ⋅k_z ⋅s   4⋅C⋅kₓ ⋅k_z ⋅s   2⋅C⋅k_
# ───── + ────────────── + ────────── + ────────────── + ────────────── + ──────
#              R_m            R_m             R                R              R
#
#
#  6           6    2         4    4         2    6          8
# z ⋅s   2⋅C⋅kₓ ⋅k_z    6⋅C⋅kₓ ⋅k_z    6⋅C⋅kₓ ⋅k_z    2⋅C⋅k_z      2  4        2
# ──── + ──────────── + ──────────── + ──────────── + ──────── + kₓ ⋅s  - 2⋅k_z
#           R⋅R_m          R⋅R_m          R⋅R_m        R⋅R_m
#
#
#                                   4  3       2    2           2    2  3
#     2      2  4        2  2   2⋅kₓ ⋅s    4⋅kₓ ⋅k_z ⋅q⋅s   4⋅kₓ ⋅k_z ⋅s    8⋅kₓ
# ⋅q⋅s  + k_z ⋅s  + 4⋅k_z ⋅s  + ──────── - ────────────── + ───────────── + ────
#                                 R_m           R_m              R_m
#
#
# 2    2          4            4  3        4       6  2       4    2         4
#  ⋅k_z ⋅s   4⋅k_z ⋅q⋅s   2⋅k_z ⋅s    8⋅k_z ⋅s   kₓ ⋅s    2⋅kₓ ⋅k_z ⋅q   3⋅kₓ ⋅k
# ──────── - ────────── + ───────── + ──────── + ────── - ──────────── + ───────
# R_m           R_m          R_m        R_m          2           2
#                                                 R_m         R_m             R_
#
#   2  2       4    2       2    4         2    4  2       2    4        6
# _z ⋅s    4⋅kₓ ⋅k_z    4⋅kₓ ⋅k_z ⋅q   3⋅kₓ ⋅k_z ⋅s    8⋅kₓ ⋅k_z    2⋅k_z ⋅q   k
# ────── + ────────── - ──────────── + ───────────── + ────────── - ──────── + ─
#  2             2             2               2             2           2
# m           R_m           R_m             R_m           R_m         R_m
#
#   6  2        6       4  3       2    2  3        4  3       6  2        4
# _z ⋅s    4⋅k_z    2⋅kₓ ⋅s    4⋅kₓ ⋅k_z ⋅s    2⋅k_z ⋅s    4⋅kₓ ⋅s    12⋅kₓ ⋅k_z
# ────── + ────── + ──────── + ───────────── + ───────── + ──────── + ──────────
#     2        2       R             R             R        R⋅R_m         R⋅R_m
#  R_m      R_m
#
# 2  2        2    4  2        6  2       8         6    2          4    4
#  ⋅s    12⋅kₓ ⋅k_z ⋅s    4⋅k_z ⋅s    2⋅kₓ ⋅s   8⋅kₓ ⋅k_z ⋅s   12⋅kₓ ⋅k_z ⋅s   8
# ──── + ────────────── + ───────── + ─────── + ──────────── + ───────────── + ─
#            R⋅R_m          R⋅R_m           2           2               2
#                                      R⋅R_m       R⋅R_m           R⋅R_m
#
#    2    6          8       6  2       4    2  2       2    4  2      6  2
# ⋅kₓ ⋅k_z ⋅s   2⋅k_z ⋅s   kₓ ⋅s    3⋅kₓ ⋅k_z ⋅s    3⋅kₓ ⋅k_z ⋅s    k_z ⋅s    2⋅
# ─────────── + ──────── + ────── + ───────────── + ───────────── + ─────── + ──
#        2            2       2            2               2            2
#   R⋅R_m        R⋅R_m       R            R               R            R       R
#
#   8         6    2          4    4         2    6          8         10
# kₓ ⋅s   8⋅kₓ ⋅k_z ⋅s   12⋅kₓ ⋅k_z ⋅s   8⋅kₓ ⋅k_z ⋅s   2⋅k_z ⋅s     kₓ      5⋅k
# ───── + ──────────── + ───────────── + ──────────── + ──────── + ─────── + ───
# 2           2               2              2            2         2    2     2
#  ⋅R_m      R ⋅R_m          R ⋅R_m         R ⋅R_m       R ⋅R_m    R ⋅R_m     R
#
#  8    2        6    4        4    6       2    8       10
# ₓ ⋅k_z    10⋅kₓ ⋅k_z    10⋅kₓ ⋅k_z    5⋅kₓ ⋅k_z     k_z
# ─────── + ─────────── + ─────────── + ────────── + ───────
#     2        2    2        2    2       2    2      2    2
# ⋅R_m        R ⋅R_m        R ⋅R_m       R ⋅R_m      R ⋅R_m

# %%
#Rm = 4.9
#Co = 0.08
#R = Rm/0.001 #Pm = Rm/R 
#q = 3/2
func = lambdify((kx, Rm, Co, R, q), disp)
plotb = lambdify((kx, Co, R, q), disp)

# %%
a1 = func(0, 4.9, 0.08, 4.9/0.001, 3/2)
a2 = func(0, 5.3, 0.08, 5.3/0.001, 3/2)
a3 = func(0, 4.6, 0.08, 4.6/0.001, 3/2)

# %%
gr1 = lambdify(kz, a1)
gr2 = lambdify(kz, a2)
gr3 = lambdify(kz, a3)

# %%
print(gr1(1.5))
print(gr2(1.5))
print(gr3(1.5))
solve(gr3(1.5))
# Out:
# 2.25*s**4 + 2.06839285714286*s**3 + 5.78630982468242*s**2 + 4.50539989541188*s + 0.21189429515657
# 2.25*s**4 + 1.91228773584906*s**3 + 5.71712705199804*s**2 + 4.1653111501126*s + 0.0740553107108287
# 2.25*s**4 + 2.20328804347826*s**3 + 5.85046308556829*s**2 + 4.79929289441021*s + 0.33971254017915
# [-0.792174273695711, -0.0779999033683587, -0.054532476685356 - -1.562221815860
# 23⋅(-1)⋅ⅈ, -0.054532476685356 + 1.56222181586023⋅ⅈ]

# %%
kk = np.arange(0.05, 2, 0.05)
out1 = np.zeros((len(kk), 4), np.complex)
out2 = np.zeros((len(kk), 4), np.complex)
out3 = np.zeros((len(kk), 4), np.complex)
for i in range(len(kk)):
    hh1 = solve(gr1(kk[i]))
    out1[i, 0] = hh1[0]
    out1[i, 1] = hh1[1]
    out1[i, 2] = hh1[2]
    out1[i, 3] = hh1[3]
    
    #hh2 = solve(gr2(kk[i]))
    #out2[i, 0] = hh2[0]
    #out2[i, 1] = hh2[1]
    #out2[i, 2] = re(hh2[2])
    #out2[i, 3] = re(hh2[3])
    
    #hh3 = solve(gr3(kk[i]))
    #out3[i, 0] = hh3[0]
    #out3[i, 1] = hh3[1]
    #out3[i, 2] = re(hh3[2])
    #out3[i, 3] = re(hh3[3])

# %%
out1[0]
# Out:
# array([ -1.46494093e-02+0.j        ,   1.36292049e-02+0.j        ,
#         -6.12081715e-07-1.41442565j,  -6.12081715e-07+1.41442565j])

# %%
ax = plt.subplot(121)
ax.plot(kk, out1[:, 0].real)
ax.plot(kk, out1[:, 1].real, '-.')
ax.plot(kk, out1[:, 2].real, ':')
ax.plot(kk, out1[:, 3].real, '.')

#plt.plot(kk, out2[:, 0], color='red')
#plt.plot(kk, out2[:, 1], '-.',color='red')
#plt.plot(kk, out2[:, 2], ':',color='red')
#plt.plot(kk, out2[:, 3], '.',color='red')

#plt.plot(kk, out3[:, 0], color='black')
#plt.plot(kk, out3[:, 1], '-.',color='black')
#plt.plot(kk, out3[:, 2], ':',color='black')
#plt.plot(kk, out3[:, 3], '.',color='black')
ax.set_xlabel('vertical wavenumber k_z')
ax.set_ylabel('growth rate Re(s)')

ax = plt.subplot(122)
ax.plot(kk, out1[:, 0].imag)
ax.plot(kk, out1[:, 1].imag, '-.')
ax.plot(kk, out1[:, 2].imag, ':')
ax.plot(kk, out1[:, 3].imag, '.')

ax.set_xlabel('vertical wavenumber k_z')
ax.set_ylabel('frequency Im(s)')
#plt.ylim(-.1, .04)

# %%
xz1 = lambdify((kx,kz,Rm, Co, R, q),disp)

# %%
# %%time
kx = np.arange(0.05, 2, 0.05)
kz = np.arange(0.05, 2, 0.05)

out1 = np.zeros((len(kz), len(kx), 4), np.complex)
for i in range(len(kz)):
    for j in range(len(kx)):
        hh1 = solve(xz1(kz[i],kx[j],4.9, 0.08, 4.9/0.001, 3/2))
        out1[i, j, 0] = hh1[0]
        out1[i, j, 1] = hh1[1]
        out1[i, j, 2] = hh1[2]
        out1[i, j, 3] = hh1[3]
# Out:
# CPU times: user 1h 28min 34s, sys: 1min 12s, total: 1h 29min 47s
# Wall time: 1h 28min 55s

# %%
plt_extent = [kx.min(),kx.max(),kz.min(),kz.max()]
fig = plt.figure(figsize=(8,15))

ax = fig.add_subplot(421)
im = ax.imshow(out1[:,:,0].real,vmin=-2,vmax=2,extent=plt_extent,cmap='bwr',origin='lower')
ax.set_title("Real")
fig.colorbar(im)
ax = fig.add_subplot(422)
im = ax.imshow(out1[:,:,0].imag,extent=plt_extent,cmap='bwr',origin='lower')
ax.set_title("Imaginary")
fig.colorbar(im)
ax = fig.add_subplot(423)
im = ax.imshow(out1[:,:,1].real,vmin=-0.2,vmax=0.2,extent=plt_extent,cmap='bwr',origin='lower')
fig.colorbar(im)
ax = fig.add_subplot(424)
im = ax.imshow(out1[:,:,1].imag,extent=plt_extent,cmap='bwr',origin='lower')
fig.colorbar(im)

ax = fig.add_subplot(425)
im = ax.imshow(out1[:,:,2].real,vmin=-0.4,vmax=0.4,extent=plt_extent,cmap='bwr',origin='lower')
fig.colorbar(im)

ax = fig.add_subplot(426)
im = ax.imshow(out1[:,:,2].imag,vmin=-1.3,vmax=1.3,extent=plt_extent,cmap='bwr',origin='lower')
fig.colorbar(im)

ax = fig.add_subplot(427)
im = ax.imshow(out1[:,:,3].real,vmin=-0.4,vmax=0.4,extent=plt_extent,cmap='bwr',origin='lower')
fig.colorbar(im)

ax = fig.add_subplot(428)
im = ax.imshow(out1[:,:,3].imag,vmin=-1.3,vmax=1.3,extent=plt_extent,cmap='bwr',origin='lower')
fig.colorbar(im)

for ax in fig.axes[::2]:
    ax.set_xlabel(r"$k_x$",size=20)
    ax.set_ylabel(r"$k_z$",size=20)

# %%
plt.plot(kx,out1[22,:,1].real)
plt.axhline(0)

# %% [markdown]
# ## Search for degenerate modes
#
# Since there are two modes which are purely real, and two which are complex, I'll just look for degenerate modes by taking the absolute value of the difference between the two real ones and the two complex ones.

# %%
fig = plt.figure(figsize=(10,5))
ax= fig.add_subplot(121)
im = ax.imshow(np.abs(out1[:,:,0]-out1[:,:,1]),cmap='Reds')
ax.set_title("Difference between real modes")
fig.colorbar(im)
ax = fig.add_subplot(122)
im = ax.imshow(np.abs(out1[:,:,2]-out1[:,:,3]),cmap='Blues')
ax.set_title("Difference between complex modes")
fig.colorbar(im)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1158fd5f0>

# %%
ee = lambdify((kz, Rm), gg)
solve(ee(0.75, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-e4d5dc6a915b> in <module>()
# ----> 1 ee = lambdify((kz, Rm), gg)
#       2 solve(ee(0.75, 5))
#
# NameError: name 'gg' is not defined

# %%
sol1 = np.zeros((len(kk), 3), np.float_)
sol2 = np.zeros((len(kk), 3), np.float_)

for i in xrange(len(kk)):
    hh = solve(ee(kk[i]))
    sol1[i, 0] = hh[0]
    sol1[i, 1] = hh[1]

# %%
plt.plot(kk, sol1[:, 1])

# %%
mat = M.subs(B0, 1).subs(omega, 1).subs(kx, 0).subs(q, 3/2).subs(Co, 0.08).subs(Rm, 4.9).subs(R, 4.9/0.001)

# %%
out = np.zeros(len(kk))
for i in xrange(len(kk)):
    jj = solve(mat.subs(kz, kk[i]).det())
    print jj
    out[i] = jj[0]

# %%
plt.plot(kk, out, color='red')

# %%
re?
